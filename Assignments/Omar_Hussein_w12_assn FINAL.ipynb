# %% [markdown]
# # Name: Omar M. Hussein
# ## Assignment 12 Working with HTML, XML, JSON and Web APIs
# ## Part I
# ### Books
#
#
#
# 1] David copperfield by Charles Dickens: <a href="https://www.amazon.com/Copperfield-Wordsworth-Classics-Charles-Dickens/dp/185326024X">David Copperfield</a>
#
# - This book is on one of my favourite classic novels by Charles Dickens it was one of the first books i read and it is a true masterpiece.
#
# - Pages: 768 pages
# - Publisher: Wordsworth Editions Ltd
# - Language: English
# <img src="david.jpg">
#
# 2] C How to program by Paul Deitel, Harvey Deitel: <a href="https://www.amazon.com/C-How-Program-Paul-Deitel/dp/013299044X">C: How to Program</a>
#
# - This is the first programming book i read and it was my first experience with coding and programming it was written by Paul Deitel, Harvey Deitel.
#
# - Series: How to Program
# - Pages: 912 pages
# - Publisher: Prentice Hall
# - Language: English
#  <img src="c.jpg">
#
# 3] 12 Rules for Life Book by Jordan Peterson: <a href="https://www.amazon.com/12-Rules-Life-Antidote-Chaos/dp/0141988517/ref=tmm_pap_swatch_0?_encoding=UTF8&qid=1574901898&sr=1-2">12 Rules for life</a>
#
# - This is a book by one of my favourite authors his name is Dr.Jordan Peterson and it was the best selling book of the year last year.
#
# - Paperback: 448 pages
# - Publisher: Penguin
# - Language: English
#  <img src="twe.jpg">

# %% [markdown]
# # Links
# Below are the files that i created and uplouded to github
# - HTML:  <a href="https://github.com/OMS1996/DAV-5400/blob/master/books_html">Books.html</a>
# - XML :   <a href="https://github.com/OMS1996/DAV-5400/blob/master/Books.xml">Books.xml</a>
# - JSON:  <a href="https://github.com/OMS1996/DAV-5400/blob/master/Books.json">Books.json</a>

# %% [markdown]
# # Loading Libraries into the the Notebook

# %%
import os
import pandas as pd
import requests 
import bs4 as bs
import json
from lxml import objectify
from pandas.io.json import json_normalize 
import matplotlib.pyplot

# %% [markdown]
# # HTML to Data
# Reading from the HTML file uplouded on Github

# %%
# reading the HTML
books_html = pd.read_html('https://raw.githubusercontent.com/OMS1996/DAV-5400/master/books_html')
# Getting the first element
html = books_html[0]
# printing the first three elements
html
# Out:
#                                     Title                     Authors  \
# 0                       David Copperfield             Charles Dickens
# 1                        C How to program  Paul Deitel, Harvey Deitel
# 2  12 Rules for life an antidote to chaos             Jordan Peterson
#
#                  Publisher Language  Pages
# 0  Wordsworth Editions Ltd  English    768
# 1            Prentice Hall  English    912
# 2                  Penguin  English    448

# %% [markdown]
# # XML to Data
# Reading from the xml file uplouded on github and then creating a local directory to store it in so we can do the transformations freely and still be able to see the changes closely ergo avoiding all the technical issues and warning and making our jobs easier.

# %%
# Creating a file directory
file_dir = '/OmarM.H/file'

# if it does not exist create a new one
if not os.path.exists(file_dir):
    os.makedirs(file_dir)
    
# the url of the data    
url = ("https://raw.githubusercontent.com/OMS1996/DAV-5400/master/Books.xml")

# creating a request
response = requests.get(url)

#opening the content of the response and writing the xml file
with open('Books.xml', 'wb') as file:
    #Writing
    file.write(response.content)

# %% [markdown]
# Objectifiying the file and getting its root

# %%
#Books Path
path = 'Books.xml'
#parsing the data
parsed = objectify.parse(open(path))
#getting the root
root = parsed.getroot()
#Printing the root
root
# Out:
# <Element root at 0x294f29bc408>

# %% [markdown]
# Looping through entire file using the book as an Indicator and then finally appending it to the total data

# %%
#the new list
data = []
#looping through the entire xml
for elt in root.Book:
    el_data = {}
    #getting the children
    for child in elt.getchildren():
        #getting the text in the child
        el_data[child.tag] = child.text
    # Appending the data
    data.append(el_data)
data;

# %% [markdown]
# Finally transforming the data variable into a dataframe and applying some rearrangement transformations to make it look like the other dataframes

# %%
#Data frame
xml = pd.DataFrame(data)

# Re-arranging the columns
xml=xml[["Title","Authors","Publisher","Language","Pages"]]
# Printing the XML file
xml
# Out:
#                Title                   Authors                Publisher  \
# 0  David Copperfield           Charles Dickens  Wordsworth Editions Ltd
# 1   C how to program  Havey Deitel,Paul Deitel            Prentice Hall
# 2  12 Rules for life           Jordan Peterson                  Penguin
#
#   Language Pages
# 0  English   768
# 1  English   912
# 2  English   448

# %% [markdown]
# # JSON to Data

# %% [markdown]
# loading the .json file into a pandas data frame and then applying transpose and  rearrangement transformations to make it look like the other dataframes

# %%
#reading the JSON file
json = pd.read_json('https://raw.githubusercontent.com/OMS1996/DAV-5400/master/Books.json')
# Transposing and rearranging the dataframe to make it look like the rest of the data frames
json = json.transpose()[["Title","Authors","Publisher","Language","Pages"]]
# Printing
json
# Out:
#                    Title                   Authors                Publisher  \
# Book1  David Copperfield           Charles Dickens  Wordsworth Editions Ltd
# Book2   C how to program  Havey Deitel Paul Deitel            Prentice Hall
# Book3  12 Rules for life           Jordan Peterson                  Penguin
#
#       Language Pages
# Book1  English   768
# Book2  English   912
# Book3  English   448

# %% [markdown]
# ### Are the three data frames identical?
# No, they were not identical as some needed a bit of pre-processing to make them have similair structure for example the Json file needed to be transposed to look similair to the rest and it is the only one that has Books as indices instead of numbers another example would be the column order in the xml section was different from the html section and it had to be re-ordered.
#
# In conclusion they were all different

# %% [markdown]
# # Part II
# ## Connect to Top Stories API
# - <a href="https://developer.nytimes.com/docs/top-stories-product/1/overview">Top Stories API</a>
# - <a href="https://developer.nytimes.com/docs/top-stories-product/1/types/Article">Top Sories Article API for more information</a>

# %% [markdown]
# # Account,API, Key and Application Details
# - Acount=ohussein@mail.yu.com
# - Key_generated=1jhlRFfbtvGKD3rTFxPkFzxdqKCPTN08
# - API in use Top Stories
# - Application name= Assn12
# - created 2019-11-28
# - App ID 5b19ccf3-ae40-4401-8bcf-86144a1cf44b
#
# # How to query the data base ?
#
# https://api.nytimes.com/svc/topstories/v2/ + the stories you are interested in + .json? + api-key=1jhlRFfbtvGKD3rTFxPkFzxdqKCPTN08"

# %% [markdown]
# ## 1.Health from top stories
# Reading the Json file

# %%
# Getting the health URL
health_url= "https://api.nytimes.com/svc/topstories/v2/health.json?api-key=1jhlRFfbtvGKD3rTFxPkFzxdqKCPTN08"

nyt_health=pd.read_json(health_url)
nyt_health.head(4)
# Out:
#   status                                          copyright section  \
# 0     OK  Copyright (c) 2019 The New York Times Company....  health
# 1     OK  Copyright (c) 2019 The New York Times Company....  health
# 2     OK  Copyright (c) 2019 The New York Times Company....  health
# 3     OK  Copyright (c) 2019 The New York Times Company....  health
#
#                 last_updated  num_results  \
# 0  2019-11-28T20:37:23-05:00           27
# 1  2019-11-28T20:37:23-05:00           27
# 2  2019-11-28T20:37:23-05:00           27
# 3  2019-11-28T20:37:23-05:00           27
#
#                                              results
# 0  {'section': 'Health', 'subsection': '', 'title...
# 1  {'section': 'Health', 'subsection': '', 'title...
# 2  {'section': 'Health', 'subsection': '', 'title...
# 3  {'section': 'Health', 'subsection': '', 'title...

# %% [markdown]
# The results column in the data frame is in json format so that needs to be rectified by normalising it through json_normalize()

# %%
x=nyt_health.results[0]
x
# Out:
# {'section': 'Health',
#  'subsection': '',
#  'title': 'Don’t Get Mad, but ‘Hangry’ Isn’t Really Angry',
#  'abstract': 'Anger comes in many flavors, it turns out, and the hunger-induced variety isn’t quite like the others.',
#  'url': 'https://www.nytimes.com/2019/11/27/health/food-anger-emotion-psychology.html',
#  'byline': 'By BENEDICT CAREY',
#  'item_type': 'Article',
#  'updated_date': '2019-11-27T08:44:35-05:00',
#  'created_date': '2019-11-27T05:00:31-05:00',
#  'published_date': '2019-11-27T05:00:31-05:00',
#  'material_type_facet': '',
#  'kicker': '',
#  'des_facet': ['Emotions',
#   'Psychology and Psychologists',
#   'Food',
#   'your-feed-science',
#   'your-feed-health'],
#  'org_facet': [],
#  'per_facet': ['MacCormack, Jennifer Kay',
#   'Faber, Nadira',
#   'Hausser, Jan',
#   'Van Lange, Paul A.M.'],
#  'geo_facet': [],
#  'multimedia': [{'url': 'https://static01.nyt.com/images/2019/12/03/science/27SCI-MIND/27SCI-MIND-thumbStandard-v2.jpg',
#    'format': 'Standard Thumbnail',
#    'height': 75,
#    'width': 75,
#    'type': 'image',
#    'subtype': 'photo',
#    'caption': '',
#    'copyright': 'Bianca Bagnarelli'},
#   {'url': 'https://static01.nyt.com/images/2019/12/03/science/27SCI-MIND/27SCI-MIND-thumbLarge-v2.jpg',
#    'format': 'thumbLarge',
#    'height': 150,
#    'width': 150,
#    'type': 'image',
#    'subtype': 'photo',
#    'caption': '',
#    'copyright': 'Bianca Bagnarelli'},
#   {'url': 'https://static01.nyt.com/images/2019/12/03/science/27SCI-MIND/27SCI-MIND-articleInline-v2.jpg',
#    'format': 'Normal',
#    'height': 120,
#    'width': 190,
#    'type': 'image',
#    'subtype': 'photo',
#    'caption': '',
#    'copyright': 'Bianca Bagnarelli'},
#   {'url': 'https://static01.nyt.com/images/2019/12/03/science/27SCI-MIND/03MIND-mediumThreeByTwo210.jpg',
#    'format': 'mediumThreeByTwo210',
#    'height': 140,
#    'width': 210,
#    'type': 'image',
#    'subtype': 'photo',
#    'caption': '',
#    'copyright': 'Bianca Bagnarelli'},
#   {'url': 'https://static01.nyt.com/images/2019/12/03/science/27SCI-MIND/03MIND-superJumbo.jpg',
#    'format': 'superJumbo',
#    'height': 1365,
#    'width': 2048,
#    'type': 'image',
#    'subtype': 'photo',
#    'caption': '',
#    'copyright': 'Bianca Bagnarelli'}],
#  'short_url': 'https://nyti.ms/2Dk89t9'}

# %% [markdown]
# Normalising the results coloumn to get its subcomponents and add them as their own seperate coloumns

# %%
resultsdf=json_normalize(nyt_health.results)
json_normalize(nyt_health.results).head(2)
# Out:
#                                             abstract               byline  \
# 0  Anger comes in many flavors, it turns out, and...    By BENEDICT CAREY
# 1  A large study found that M.R.I.s detected tumo...  By RONI CARYN RABIN
#
#                 created_date  \
# 0  2019-11-27T05:00:31-05:00
# 1  2019-11-27T17:00:07-05:00
#
#                                            des_facet geo_facet item_type  \
# 0  [Emotions, Psychology and Psychologists, Food,...        []   Article
# 1  [your-feed-science, Mammography, Women and Gir...        []   Article
#
#   kicker material_type_facet  \
# 0
# 1
#
#                                           multimedia  \
# 0  [{'url': 'https://static01.nyt.com/images/2019...
# 1  [{'url': 'https://static01.nyt.com/images/2019...
#
#                            org_facet  \
# 0                                 []
# 1  [New England Journal of Medicine]
#
#                                            per_facet  \
# 0  [MacCormack, Jennifer Kay, Faber, Nadira, Haus...
# 1                                                 []
#
#               published_date section                short_url subsection  \
# 0  2019-11-27T05:00:31-05:00  Health  https://nyti.ms/2Dk89t9
# 1  2019-11-27T17:00:07-05:00  Health  https://nyti.ms/2pYhbsX
#
#                                                title  \
# 0     Don’t Get Mad, but ‘Hangry’ Isn’t Really Angry
# 1  M.R.I.s Can Better Detect Cancer in Women With...
#
#                 updated_date  \
# 0  2019-11-27T08:44:35-05:00
# 1  2019-11-27T23:45:45-05:00
#
#                                                  url
# 0  https://www.nytimes.com/2019/11/27/health/food...
# 1  https://www.nytimes.com/2019/11/27/health/dens...

# %% [markdown]
# ### Deleting the duplicate results column after normalizing it and replacing it with its subcomponents forming one large data frame that entails all of our data in seperate coloumns.

# %%
del nyt_health['results']
new_health = pd.concat([nyt_health, resultsdf], axis=1)
new_health['published_date']=pd.to_datetime(new_health.published_date)
new_health.head(3)
# Out:
#   status                                          copyright section  \
# 0     OK  Copyright (c) 2019 The New York Times Company....  health
# 1     OK  Copyright (c) 2019 The New York Times Company....  health
# 2     OK  Copyright (c) 2019 The New York Times Company....  health
#
#                 last_updated  num_results  \
# 0  2019-11-28T20:37:23-05:00           27
# 1  2019-11-28T20:37:23-05:00           27
# 2  2019-11-28T20:37:23-05:00           27
#
#                                             abstract               byline  \
# 0  Anger comes in many flavors, it turns out, and...    By BENEDICT CAREY
# 1  A large study found that M.R.I.s detected tumo...  By RONI CARYN RABIN
# 2  The electronic implants reduced Parkinson’s sy...      By DENISE GRADY
#
#                 created_date  \
# 0  2019-11-27T05:00:31-05:00
# 1  2019-11-27T17:00:07-05:00
# 2  2019-11-27T16:00:09-05:00
#
#                                            des_facet  \
# 0  [Emotions, Psychology and Psychologists, Food,...
# 1  [your-feed-science, Mammography, Women and Gir...
# 2  [Parkinson's Disease, Medical Devices, Brain, ...
#
#                             geo_facet  ...  \
# 0                                  []  ...
# 1                                  []  ...
# 2  [Lucerne (Switzerland), Australia]  ...
#
#                                           multimedia  \
# 0  [{'url': 'https://static01.nyt.com/images/2019...
# 1  [{'url': 'https://static01.nyt.com/images/2019...
# 2  [{'url': 'https://static01.nyt.com/images/2019...
#
#                                            org_facet  \
# 0                                                 []
# 1                  [New England Journal of Medicine]
# 2  [Medtronic Inc, Abbott Laboratories, Boston Sc...
#
#                                            per_facet  \
# 0  [MacCormack, Jennifer Kay, Faber, Nadira, Haus...
# 1                                                 []
# 2                                                 []
#
#              published_date section                short_url subsection  \
# 0 2019-11-27 05:00:31-05:00  Health  https://nyti.ms/2Dk89t9
# 1 2019-11-27 17:00:07-05:00  Health  https://nyti.ms/2pYhbsX
# 2 2019-11-27 16:00:09-05:00  Health  https://nyti.ms/2XQK9Hw
#
#                                                title  \
# 0     Don’t Get Mad, but ‘Hangry’ Isn’t Really Angry
# 1  M.R.I.s Can Better Detect Cancer in Women With...
# 2          Swimmers Beware of Deep Brain Stimulation
#
#                 updated_date  \
# 0  2019-11-27T08:44:35-05:00
# 1  2019-11-27T23:45:45-05:00
# 2  2019-11-27T16:19:07-05:00
#
#                                                  url
# 0  https://www.nytimes.com/2019/11/27/health/food...
# 1  https://www.nytimes.com/2019/11/27/health/dens...
# 2  https://www.nytimes.com/2019/11/27/health/swim...
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Now that we have the data how about we identify on which day has the most published titles for health?

# %%
new_health.published_date.dt.weekday_name.value_counts().plot.barh();

# %% [markdown]
# ## 2. Science from top stories
# Performing the same steps for Science as we did for health

# %%
science ="https://api.nytimes.com/svc/topstories/v2/science.json?api-key=1jhlRFfbtvGKD3rTFxPkFzxdqKCPTN08"
nyt_science=pd.read_json(science)
nyt_science.head(4)
# Out:
#   status                                          copyright  section  \
# 0     OK  Copyright (c) 2019 The New York Times Company....  science
# 1     OK  Copyright (c) 2019 The New York Times Company....  science
# 2     OK  Copyright (c) 2019 The New York Times Company....  science
# 3     OK  Copyright (c) 2019 The New York Times Company....  science
#
#                 last_updated  num_results  \
# 0  2019-11-28T20:37:19-05:00           21
# 1  2019-11-28T20:37:19-05:00           21
# 2  2019-11-28T20:37:19-05:00           21
# 3  2019-11-28T20:37:19-05:00           21
#
#                                              results
# 0  {'section': 'Science', 'subsection': '', 'titl...
# 1  {'section': 'Science', 'subsection': '', 'titl...
# 2  {'section': 'Science', 'subsection': '', 'titl...
# 3  {'section': 'Science', 'subsection': '', 'titl...

# %% [markdown]
# Normalizing

# %%
results_df=json_normalize(nyt_science.results)
json_normalize(nyt_science.results).head(1)
# Out:
#                                        abstract             byline  \
# 0  Without that texture, there’d be none of us.  By DENNIS OVERBYE
#
#                 created_date  \
# 0  2019-11-26T05:00:25-05:00
#
#                                            des_facet geo_facet item_type  \
# 0  [Space and Astronomy, Stars and Galaxies, Nobe...        []   Article
#
#   kicker material_type_facet  \
# 0
#
#                                           multimedia org_facet  \
# 0  [{'url': 'https://static01.nyt.com/images/2019...        []
#
#                                            per_facet  \
# 0  [Guth, Alan H, Peebles, James, Smoot, George F...
#
#               published_date  section                short_url subsection  \
# 0  2019-11-26T05:00:25-05:00  Science  https://nyti.ms/34pu6ms
#
#                                               title  \
# 0  In Praise of Lumpy Gravy From the Cosmic Kitchen
#
#                 updated_date  \
# 0  2019-11-26T09:17:27-05:00
#
#                                                  url
# 0  https://www.nytimes.com/2019/11/26/science/ast...

# %% [markdown]
# ### Deleting the duplicate results column after normalizing it and replacing it with its subcomponents forming one large data frame that entails all of our data in seperate coloumns

# %%
del nyt_science['results']
new_science = pd.concat([nyt_science, results_df], axis=1)
new_science['published_date']=pd.to_datetime(new_science.published_date)
new_science.head(3)
# Out:
#   status                                          copyright  section  \
# 0     OK  Copyright (c) 2019 The New York Times Company....  science
# 1     OK  Copyright (c) 2019 The New York Times Company....  science
# 2     OK  Copyright (c) 2019 The New York Times Company....  science
#
#                 last_updated  num_results  \
# 0  2019-11-28T20:37:19-05:00           21
# 1  2019-11-28T20:37:19-05:00           21
# 2  2019-11-28T20:37:19-05:00           21
#
#                                             abstract             byline  \
# 0       Without that texture, there’d be none of us.  By DENNIS OVERBYE
# 1  Biology. Chemistry. Physics. It’s all there on...  By MICHAEL ROSTON
# 2  Mysterious 609-million-year-old balls of cells...     By CARL ZIMMER
#
#                 created_date  \
# 0  2019-11-26T05:00:25-05:00
# 1  2017-11-20T17:02:32-05:00
# 2  2019-11-27T11:00:09-05:00
#
#                                            des_facet geo_facet  ...  \
# 0  [Space and Astronomy, Stars and Galaxies, Nobe...        []  ...
# 1  [Thanksgiving Day, Food, Science and Technolog...        []  ...
# 2  [Animals, Paleontology, Fossils, Evolution (Bi...   [China]  ...
#
#                                           multimedia org_facet  \
# 0  [{'url': 'https://static01.nyt.com/images/2019...        []
# 1  [{'url': 'https://static01.nyt.com/images/2017...        []
# 2  [{'url': 'https://static01.nyt.com/images/2019...        []
#
#                                            per_facet  \
# 0  [Guth, Alan H, Peebles, James, Smoot, George F...
# 1                                                 []
# 2  [Knoll, Andrew, Xiao, Shuhai, Donoghue, Philip...
#
#              published_date  section                short_url subsection  \
# 0 2019-11-26 05:00:25-05:00  Science  https://nyti.ms/34pu6ms
# 1 2017-11-20 17:02:32-05:00  Science  https://nyti.ms/2jI3U46
# 2 2019-11-27 11:00:09-05:00  Science  https://nyti.ms/34oHQ0Q
#
#                                                title  \
# 0   In Praise of Lumpy Gravy From the Cosmic Kitchen
# 1  A Helping of Science With Your Thanksgiving Di...
# 2             Is This the First Fossil of an Embryo?
#
#                 updated_date  \
# 0  2019-11-26T09:17:27-05:00
# 1  2018-11-21T22:01:34-05:00
# 2  2019-11-27T11:00:09-05:00
#
#                                                  url
# 0  https://www.nytimes.com/2019/11/26/science/ast...
# 1  https://www.nytimes.com/2017/11/20/science/tha...
# 2  https://www.nytimes.com/2019/11/27/science/fos...
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Now that we have the data how about we identify on which day has the most published titles for science?

# %%
new_science.published_date.dt.weekday_name.value_counts().plot.barh();

# %% [markdown]
# # __Thank you from Omar M. Hussein__
